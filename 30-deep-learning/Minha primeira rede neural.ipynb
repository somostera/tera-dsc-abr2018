# %% [markdown]
# # Minha primeira rede neural
#
# Vamos construir uma rede neural simples utilizando Numpy que vocês já conhecem!

# %% [markdown]
# ## Pacotes necessários

# %%
import numpy as np

# %% [markdown]
# ## Entrada da rede neural e função de ativação
#
# Aplicam a não linearidade nos dados já que cada neurônio representa a equação de uma reta:
#
# xw + b = y
#
# Funções de ativação são responsáveis por decidir qual deve ser a saída do neurônio dada a entrada e os pesos
#
#
# ![Funções de ativação](http://adilmoujahid.com/images/activation.png)

# %% [markdown]
# ## Vamos implementar a função de ativação?

# %%
def sigmoid(x):
    # TODO: Implement sigmoid function
    pass

inputs = np.array([0.7, 0.3])
weights = np.array([0.1, 0.8])
bias = -0.1

# TODO: Calculate the output
output = None

print('Output:')
print(output)
# Out:
# Output:
# None

# %% [markdown]
# ## Solução

# %%
###SOLUCAO
import numpy as np

def sigmoid(x):
    # TODO: Implement sigmoid function
    return 1/(1+ np.exp(-x))

inputs = np.array([0.7, 0.3])
weights = np.array([0.1, 0.8])
bias = -0.1

# TODO: Calculate the output
output = sigmoid(np.dot(inputs,weights) + bias)

print('Output:')
print(output)
# Out:
# Output:
# 0.5523079095743253

# %% [markdown]
# ## Como os pesos são aprendidos?

# %% [markdown]
# ## Gradiente descendente!
#
# ![Gradiente Descendente](https://cdn-images-1.medium.com/max/1600/0*rBQI7uBhBKE8KT-X.png)

# %% [markdown]
# ## Calcular o erro entre a saída da rede e a saída esperada
#
#
# Para aprendermos os pesos a partir dos dados precisamos primeiro calcular uma** medida de erro entre o resultado previsto e o resultado real**.
#
# ![alt text](data:image/png;base64,...)
#
# * ŷ: é o resultado previsto
# * y: é o resultado real
# * j: unidades de saída da rede
# * 𝜇: dados de entrada

# %%
import numpy as np


def sigmoid(x):
    """
    Calculate sigmoid
    """
    return 1 / (1 + np.exp(-x))


x = np.array([0.5, 0.1, -0.2])
target = 0.6
learnrate = 0.5

weights_input_hidden = np.array([[0.5, -0.6],
                                 [0.1, -0.2],
                                 [0.1, 0.7]])

weights_hidden_output = np.array([0.1, -0.3])

## Forward pass
hidden_layer_input = np.dot(x, weights_input_hidden)
hidden_layer_output = sigmoid(hidden_layer_input)

output_layer_in = np.dot(hidden_layer_output, weights_hidden_output)
output = sigmoid(output_layer_in)

## Backwards pass
## TODO: Calculate output error
error = None

# TODO: Calculate error term for output layer
output_error_term = None

# TODO: Calculate error term for hidden layer
hidden_error_term = None

# TODO: Calculate change in weights for hidden layer to output layer
delta_w_h_o = None

# TODO: Calculate change in weights for input layer to hidden layer
delta_w_i_h = None

print('Change in weights for hidden layer to output layer:')
print(delta_w_h_o)
print('Change in weights for input layer to hidden layer:')
print(delta_w_i_h)

# %% [markdown]
# ## Solução - Cálculo do erro

# %%
##Solucao
import numpy as np


def sigmoid(x):
    """
    Calculate sigmoid
    """
    return 1 / (1 + np.exp(-x))


x = np.array([0.5, 0.1, -0.2])
target = 0.6
learnrate = 0.5

weights_input_hidden = np.array([[0.5, -0.6],
                                 [0.1, -0.2],
                                 [0.1, 0.7]])

weights_hidden_output = np.array([0.1, -0.3])

## Forward pass
hidden_layer_input = np.dot(x, weights_input_hidden)
hidden_layer_output = sigmoid(hidden_layer_input)

output_layer_in = np.dot(hidden_layer_output, weights_hidden_output)
output = sigmoid(output_layer_in)

## Backwards pass
## TODO: Calculate error
error = target - output

# TODO: Calculate error term for output layer
output_error_term = None

# TODO: Calculate error term for hidden layer
hidden_error_term = None

# TODO: Calculate change in weights for hidden layer to output layer
delta_w_h_o = None

# TODO: Calculate change in weights for input layer to hidden layer
delta_w_i_h = None

print('Change in weights for hidden layer to output layer:')
print(delta_w_h_o)
print('Change in weights for input layer to hidden layer:')
print(delta_w_i_h)

# %% [markdown]
# ## Cálculo do erro para a camada de saída
#
# ![alt text](data:image/png;base64,...)

# %%
##Solucao
import numpy as np


def sigmoid(x):
    """
    Calculate sigmoid
    """
    return 1 / (1 + np.exp(-x))


x = np.array([0.5, 0.1, -0.2])
target = 0.6
learnrate = 0.5

weights_input_hidden = np.array([[0.5, -0.6],
                                 [0.1, -0.2],
                                 [0.1, 0.7]])

weights_hidden_output = np.array([0.1, -0.3])

## Forward pass
hidden_layer_input = np.dot(x, weights_input_hidden)
hidden_layer_output = sigmoid(hidden_layer_input)

output_layer_in = np.dot(hidden_layer_output, weights_hidden_output)
output = sigmoid(output_layer_in)

## Backwards pass
## TODO: Calculate error
error = target - output

# TODO: Calculate error term for output layer
output_error_term = None

# TODO: Calculate error term for hidden layer
hidden_error_term = None

# TODO: Calculate change in weights for hidden layer to output layer
delta_w_h_o = None

# TODO: Calculate change in weights for input layer to hidden layer
delta_w_i_h = None

print('Change in weights for hidden layer to output layer:')
print(delta_w_h_o)
print('Change in weights for input layer to hidden layer:')
print(delta_w_i_h)

# %% [markdown]
# ## Solução - Cálculo do erro para a camada de saída

# %%
##Solucao
import numpy as np


def sigmoid(x):
    """
    Calculate sigmoid
    """
    return 1 / (1 + np.exp(-x))


x = np.array([0.5, 0.1, -0.2])
target = 0.6
learnrate = 0.5

weights_input_hidden = np.array([[0.5, -0.6],
                                 [0.1, -0.2],
                                 [0.1, 0.7]])

weights_hidden_output = np.array([0.1, -0.3])

## Forward pass
hidden_layer_input = np.dot(x, weights_input_hidden)
hidden_layer_output = sigmoid(hidden_layer_input)

output_layer_in = np.dot(hidden_layer_output, weights_hidden_output)
output = sigmoid(output_layer_in)

## Backwards pass
## TODO: Calculate error
error = target - output

# TODO: Calculate error gradient for output layer
del_err_output = error*(sigmoid(output_layer_in)*(1-sigmoid(output_layer_in)))

# TODO: Calculate error term for hidden layer
hidden_error_term = None

# TODO: Calculate change in weights for hidden layer to output layer
delta_w_h_o = None

# TODO: Calculate change in weights for input layer to hidden layer
delta_w_i_h = None

print('Change in weights for hidden layer to output layer:')
print(delta_w_h_o)
print('Change in weights for input layer to hidden layer:')
print(delta_w_i_h)
# Out:
# Change in weights for hidden layer to output layer:
# None
# Change in weights for input layer to hidden layer:
# None

# %% [markdown]
# ## Cálculo do delta para os pesos
#
# ![alt text](data:image/png;base64,...)

# %%
##Solucao
import numpy as np


def sigmoid(x):
    """
    Calculate sigmoid
    """
    return 1 / (1 + np.exp(-x))


x = np.array([0.5, 0.1, -0.2])
target = 0.6
learnrate = 0.5

weights_input_hidden = np.array([[0.5, -0.6],
                                 [0.1, -0.2],
                                 [0.1, 0.7]])

weights_hidden_output = np.array([0.1, -0.3])

## Forward pass
hidden_layer_input = np.dot(x, weights_input_hidden)
hidden_layer_output = sigmoid(hidden_layer_input)

output_layer_in = np.dot(hidden_layer_output, weights_hidden_output)
output = sigmoid(output_layer_in)

## Backwards pass
## TODO: Calculate error
error = target - output

# TODO: Calculate error gradient for output layer
del_err_output = error*(sigmoid(output_layer_in)*(1-sigmoid(output_layer_in)))

# TODO: Calculate error term for hidden layer
hidden_error_term = None

# TODO: Calculate change in weights for hidden layer to output layer
delta_w_h_o = None

# TODO: Calculate change in weights for input layer to hidden layer
delta_w_i_h = None

print('Change in weights for hidden layer to output layer:')
print(delta_w_h_o)
print('Change in weights for input layer to hidden layer:')
print(delta_w_i_h)

# %% [markdown]
# ## Solução - Cálculo do delta para os pesos

# %%
##Solucao
import numpy as np


def sigmoid(x):
    """
    Calculate sigmoid
    """
    return 1 / (1 + np.exp(-x))


x = np.array([0.5, 0.1, -0.2])
target = 0.6
learnrate = 0.5

weights_input_hidden = np.array([[0.5, -0.6],
                                 [0.1, -0.2],
                                 [0.1, 0.7]])

weights_hidden_output = np.array([0.1, -0.3])

## Forward pass
hidden_layer_input = np.dot(x, weights_input_hidden)
hidden_layer_output = sigmoid(hidden_layer_input)

output_layer_in = np.dot(hidden_layer_output, weights_hidden_output)
output = sigmoid(output_layer_in)

## Backwards pass
## TODO: Calculate error
error = target - output

# TODO: Calculate error gradient for output layer
del_err_output = error*(sigmoid(output_layer_in)*(1-sigmoid(output_layer_in)))

# TODO: Calculate error gradient for hidden layer
error_hidden = np.dot(del_err_output, weights_hidden_output) 
del_err_hidden = error_hidden *(sigmoid(hidden_layer_input)*(1-sigmoid(hidden_layer_input)))

# TODO: Calculate change in weights for hidden layer to output layer
delta_w_h_o = learnrate*del_err_output*hidden_layer_output

# TODO: Calculate change in weights for input layer to hidden layer
delta_w_i_h = learnrate*del_err_hidden*x[:, None]

print('Change in weights for hidden layer to output layer:')
print(delta_w_h_o)
print('Change in weights for input layer to hidden layer:')
print(delta_w_i_h)
