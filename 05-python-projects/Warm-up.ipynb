# %%
profissoes = ['adestradorx de dinossauros', 
              'colecionadorx de tampinhas de PET', 
              'empinadorx de pipa em ventilador', 
              'cabeleireirx de pulga', 
              'cozinheirx gourmet para cachorros', 
              'açougueirx de grilos', 
              'escrivãx de conversas no whatsapp', 
              'juizx de briga de rua', 
              'sommelier de vinagre', 
              'instrutorx de abertura de porta automática', 
              'cavaleirx de touro mecânico', 
              'treinadorx de boneco de posto', 
              'assopradorx de bolhas na água com gás', 
              'chacoalhadorx de latinhas de cerveja',
              'flanelinha de avião', 
              'blogueirx de unboxing de bananas', 
              'degustadorx de bala 7 belo', 
              'coach de demissão', 
              'croupier de poker online', 
              'salva-vidas de piscina de bolinha', 
              'enceradorx de asfalto', 
              'perfumista de pipoca de microondas',
              'acendedorx de lareira elétrica', 
              'lenhadorx de bonsai', 
              'jardineirx de flores de plástico', 
              'coringa de baralho', 
              'encanadorx de tubo de ensaio', 
              'jogadorx de tênis descalço', 
              'engenheirx de desculpas', 
              'instaladorx de cordão umbilical', 
              'pirata de aquário']

pessoas = [('Luisa', 'varrer a feira', 4), 
           ('Wilson', 'ser arranhada por gatinhos', 19), 
           ('Fulano', 'fazer seguro de vida do lobo mau', 24)]

def contar_historia(pessoa):
    nome = pessoa[0]
    convida_a_filo = pessoa[1]
    dia_nascimento = pessoa[2]
    profissao = profissoes[dia_nascimento - 1]
    
    print('{0}, que é {1}, e convida a Filó para {2}.'.format(nome, profissao, convida_a_filo))
    print()
    

    
print('Filó é uma filósofa e estava lendo Kant (porque filósofos fazem isso sempre).')
print()
print('De repente ela recebe uma ligação de...')
    
for pessoa in pessoas:
    contar_historia(pessoa)
    print('Filó então decide ligar para...')

    
    
print()
print('--------')
print()
print('Lista de profissões por dia em que a pessoa nasceu')
for index, profissao in enumerate(profissoes):
    print('{0} - {1}'.format(index, profissao))
# Out:
# Filó é uma filósofa e estava lendo Kant (porque filósofos fazem isso sempre).
#
# De repente ela recebe uma ligação de...
# Luisa, que é cabeleireirx de pulga, e convida a Filó para varrer a feira.
#
# Filó então decide ligar para...
# Wilson, que é croupier de poker online, e convida a Filó para ser arranhada por gatinhos.
#
# Filó então decide ligar para...
# Fulano, que é lenhadorx de bonsai, e convida a Filó para fazer seguro de vida do lobo mau.
#
# Filó então decide ligar para...
#
# --------
#
# Lista de profissões por dia em que a pessoa nasceu
# 0 - adestradorx de dinossauros
# 1 - colecionadorx de tampinhas de PET
# 2 - empinadorx de pipa em ventilador
# 3 - cabeleireirx de pulga
# 4 - cozinheirx gourmet para cachorros
# 5 - açougueirx de grilos
# 6 - escrivãx de conversas no whatsapp
# 7 - juizx de briga de rua
# 8 - sommelier de vinagre
# 9 - instrutorx de abertura de porta automática
# 10 - cavaleirx de touro mecânico
# 11 - treinadorx de boneco de posto
# ...
